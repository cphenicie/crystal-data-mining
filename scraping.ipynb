# %%
from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
import re
import numpy as np
import scipy as sp
import scipy.io
import os
import pickle
import pandas as pd
from itertools import permutations
import urllib.request
import pymatgen as mg

# %% [markdown]
# # Download the international tables

# %%
# Had to download geckodriver from https://github.com/mozilla/geckodriver/releases
# Moved it to a known location, and put that location in PATH
# Still had problems, so pointed selenium to the correct firefox executable
# Works!
binary = FirefoxBinary(r'C:\Program Files\Mozilla Firefox\firefox.exe')
driver = webdriver.Firefox(firefox_binary=binary)

# %%
ngroups = 230
international_tables = [{} for _ in range(ngroups+1)] # We will index this by the actual number in the list

for igroup in range(1, ngroups+1):
    
    # Pull up the page corresponding to the group number
    driver.get('http://www.cryst.ehu.es/cgi-bin/cryst/programs/nph-wp-list') # Waits for page to load
    
    text_box = driver.find_element_by_name('gnum') # Found empirically
    text_box.clear() # Clear in case there's any text still there
    text_box.send_keys('%i' %igroup)
    standard_button = driver.find_element_by_name('standard')
    standard_button.click()
    
    # Extract information from the page
    heading1 = driver.find_element_by_tag_name('h2') # Found empirically
    head = heading1.text
    hm_name = re.search('Group (.+?) \(', head).group(1)
    table = driver.find_elements_by_tag_name('table')[1] # Second table on the page, found empirically
    table_text = table.text
    
    # Parse the information from the table
    table_lines = table_text.split('\n')
    r = re.compile("^[0-9]+") # Find the elements that begin with a number (which is Wycoff multiplicity)
    newlist = list(filter(r.match, table_lines)) # Read Note
    split_list = np.array([element.split(" ", 2) for element in newlist]) # Split into 3 groups of str
    
    row_names = ["multiplicity", "letter", "symmetry"]
    international_tables[igroup]['name'] = hm_name
    international_tables[igroup]['wyckoff table'] = {name: split_list[:,i] for i, name in enumerate(row_names)}
    
path = os.getcwd()
file_name = "international_tables.pickle"
with open(os.path.join(path, file_name), 'wb') as f:
        pickle.dump(international_tables, f, pickle.HIGHEST_PROTOCOL)

# %%
international_tables[136]['wyckoff table']
# Out:
# {'letter': array(['k', 'j', 'i', 'h', 'g', 'f', 'e', 'd', 'c', 'b', 'a'], dtype='<U5'),
#  'multiplicity': array(['16', '8', '8', '8', '4', '4', '4', '4', '4', '2', '2'],
#        dtype='<U5'),
#  'symmetry': array(['1', '..m', 'm..', '2..', 'm.2 m', 'm.2 m', '2.m m', '-4..',
#         '2/m..', 'm.m m', 'm.m m'], dtype='<U5')}

# %%
international_dict = {str(i): entry for i, entry in enumerate(international_tables) if i>0}
# Out:
# {'name': 'P1',
#  'wyckoff table': {'letter': array(['a'], dtype='<U1'),
#   'multiplicity': array(['1'], dtype='<U1'),
#   'symmetry': array(['1'], dtype='<U1')}}

# %% [markdown]
# # Search the international tables for good symmetries

# %%
best_sym = ['C3h', 'D2', 'D2d', 'D3', 'D3h', 'D4', 'D6', 'S4', 'T']
good_sym = ['Ci', 'C2h', 'C4h', 'C6h', 'D2h', 'D3d', 'D4h', 'D6h', 'S6', 'Th']

# %%
path = r'.'
file_name = "international_tables.pickle"
with open(os.path.join(path, file_name), 'rb') as fp:
    table = pickle.load(fp)

# %%
path = r'.'
file_name = "hm_schoenflies.csv"
conversion_df = pd.read_csv(os.path.join(path, file_name), header=None)

# %%
sh_to_hm = dict(zip(conversion_df[0], conversion_df[1]))

# %%
good_sym_hm = [sh_to_hm[sym] for sym in good_sym]
best_sym_hm = [sh_to_hm[sym] for sym in best_sym]
best_sym_hm
# Out:
# ['-6', '222', '-42m', '32', '-62m', '422', '622', '-4', '23']

# %%
# Define some helper functions to query this inernational tables for a list of point groups

def str_remove(string, remove_list):
    """ Removes all instances of all characters in remove_list from string """
    
    return string.translate({ord(x): '' for x in remove_list})

def sym_pos(sym_list, group_num):
    """ returns a list of the wyckoff positions in group_num that have a symmetry element in sym_list"""
    
    sym_list_perm = ["".join(arr) for sym in sym_list for arr in list(permutations(sym))] # All permutations
    # Empirically, seemed that adding permutations didn't change the list, but let's keep it anyway
    curr_table = table[group_num]['wyckoff table']
    regex = r"(?=("+'|'.join(sym_list_perm)+r"))"
    clean_sym = [str_remove(el, [' ', '.']) for el in curr_table['symmetry']]
    sym_el = [re.findall(regex, sym) for sym in clean_sym]
    pts = [(curr_table['multiplicity'][i] + curr_table['letter'][i], curr_table['symmetry'][i]) 
           for i, val in enumerate(sym_el) if val]
    
    return pts

# %%
best_groups = []
ngroups = 230

for space_group in range(1, ngroups+1):
    pts = sym_pos(best_sym_hm, space_group)
    if pts:
        best_groups.append(space_group)
        
good_groups = []
ngroups = 230

for space_group in range(1, ngroups+1):
    pts = sym_pos(np.concatenate([good_sym_hm, best_sym_hm]), space_group)
    if pts:
        good_groups.append(space_group)

# %%
best_groups
# Out:
# [16,
#  21,
#  22,
#  23,
#  48,
#  49,
#  50,
#  66,
#  67,
#  68,
#  69,
#  70,
#  72,
#  81,
#  82,
#  84,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  93,
#  94,
#  97,
#  98,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  124,
#  125,
#  126,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  149,
#  150,
#  155,
#  162,
#  163,
#  165,
#  167,
#  174,
#  175,
#  176,
#  177,
#  180,
#  181,
#  182,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  201,
#  202,
#  203,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230]

# %%
bad_groups = [i for i in range(1, ngroups+1) if i not in best_groups]
len(bad_groups)
# Out:
# 123

# %%
sym_pos(['2mm'], 137)
# Out:
# [('4d', '2mm .'), ('4c', '2mm .')]

# %%
len(good_groups)
# Out:
# 145

# %%
len(best_groups)
# Out:
# 107

# %% [markdown]
# # Make a list of the bad elements

# %%
# Download the file to scrape from, and save it for later in case I/it goes offline
url = "http://easyspin.org/easyspin/documentation/isotopetable.html"
f = urllib.request.urlopen(url)
content = f.read()
content_str = content.decode('utf8', errors='ignore')
file_name = 'isotopetable.html'
# with open('isotopetable.html', 'w') as f:
#     f.write(content_str)

# %%
file_name = 'isotopetable.html'
with open('isotopetable.html', 'r') as f:
    content = f.readlines()

# %%
# Extract data
r = re.compile("^ *[0-9]+") # Find lines of the table, which being with any number of spaces then a number
table_lines = list(filter(r.match, content))
table_lines_split = [line.split() for line in table_lines]

# %%
# Extract header
r = re.compile(".*Column.*") # Find lines of the table, which being with any number of spaces then a number
header_lines = list(filter(r.match, content))
header = [line.split(": ")[1].rstrip() for line in header_lines]

# %%
isotope_table =  pd.DataFrame(table_lines_split)
isotope_table.columns = header
isotope_table
# Out:
#     #protons #nucleons radioactive *, stable - symbol           name  \
# 0          1         1                       -      H       hydrogen
# 1          1         2                       -      H       hydrogen
# 2          1         3                       *      H       hydrogen
# 3          2         3                       -     He         helium
# 4          2         4                       -     He         helium
# 5          3         6                       -     Li        lithium
# 6          3         7                       -     Li        lithium
# 7          4         9                       -     Be      beryllium
# 8          5        10                       -      B          boron
# 9          5        11                       -      B          boron
# 10         6        12                       -      C         carbon
# 11         6        13                       -      C         carbon
# 12         6        14                       *      C         carbon
# 13         7        14                       -      N       nitrogen
# 14         7        15                       -      N       nitrogen
# 15         8        16                       -      O         oxygen
# 16         8        17                       -      O         oxygen
# 17         8        18                       *      O         oxygen
# 18         9        19                       -      F       fluorine
# 19        10        20                       -     Ne           neon
# 20        10        21                       -     Ne           neon
# 21        10        22                       -     Ne           neon
# 22        11        22                       *     Na         sodium
# 23        11        23                       -     Na         sodium
# 24        12        24                       -     Mg      magnesium
# 25        12        25                       -     Mg      magnesium
# 26        12        26                       -     Mg      magnesium
# 27        13        27                       -     Al      aluminium
# 28        14        28                       -     Si        silicon
# 29        14        29                       -     Si        silicon
# ..       ...       ...                     ...    ...            ...
# 321       91         0                       -     Pa   protactinium
# 322       92       234                       *      U        uranium
# 323       92       235                       *      U        uranium
# 324       92       238                       *      U        uranium
# 325       93       237                       *     Np      neptunium
# 326       94       239                       *     Pu      plutonium
# 327       95       243                       *     Am      americium
# 328       96         0                       *     Cm         curium
# 329       97         0                       *     Bk      berkelium
# 330       98         0                       *     Cf    californium
# 331       99         0                       *     Es    einsteinium
# 332      100         0                       *     Fm        fermium
# 333      101         0                       *     Md    mendelevium
# 334      102         0                       *     No       nobelium
# 335      103         0                       *     Lr     lawrencium
# 336      104         0                       *     Rf  rutherfordium
# 337      105         0                       *     Db        dubnium
# 338      106         0                       *     Sg     seaborgium
# 339      107         0                       *     Bh        bohrium
# 340      108         0                       *     Hs        hassium
# 341      109         0                       *     Mt     meitnerium
# 342      110         0                       *     Ds   darmstadtium
# 343      111         0                       *     Rg    roentgenium
# 344      112         0                       *     Cn    copernicium
# 345      113         0                       *     Nh       nihonium
# 346      114         0                       *     Fl      flerovium
# 347      115         0                       *     Mc      moscovium
# 348      116         0                       *     Lv    livermorium
# 349      117         0                       *     Ts     tennessine
# 350      118         0                       *     Og      oganesson
#
#     spin quantum number nuclear g factor gn natural abundance, in percent  \
# 0                   0.5         +5.58569468                       99.9885
# 1                   1.0          +0.8574382                        0.0115
# 2                   0.5         +5.95799369                           0.0
# 3                   0.5         -4.25499544                      0.000137
# 4                   0.0                 0.0                     99.999863
# 5                   1.0          +0.8220473                          7.59
# 6                   1.5           +2.170951                         92.41
# 7                   1.5            -0.78495                         100.0
# 8                   3.0           +0.600215                          19.9
# 9                   1.5          +1.7924326                          80.1
# 10                  0.0                 0.0                         98.93
# 11                  0.5          +1.4048236                          1.07
# 12                  0.0                 0.0                           0.0
# 13                  1.0         +0.40376100                        99.632
# 14                  0.5         -0.56637768                         0.368
# 15                  0.0                 0.0                        99.757
# 16                  2.5           -0.757516                         0.038
# 17                  0.0                 0.0                         0.205
# 18                  0.5           +5.257736                         100.0
# 19                  0.0                 0.0                         90.48
# 20                  1.5           -0.441198                          0.27
# 21                  0.0                 0.0                          9.25
# 22                  3.0              +0.582                           0.0
# 23                  1.5           +1.478348                         100.0
# 24                  0.0                 0.0                         78.99
# 25                  2.5            -0.34218                         10.00
# 26                  0.0                 0.0                         11.01
# 27                  2.5          +1.4566028                         100.0
# 28                  0.0                 0.0                       92.2297
# 29                  0.5            -1.11058                        4.6832
# ..                  ...                 ...                           ...
# 321                -1.0                 0.0                         100.0
# 322                 0.0                 0.0                        0.0055
# 323                 3.5              -0.109                        0.7200
# 324                 0.0                 0.0                       99.2745
# 325                 2.5              +1.256                           0.0
# 326                 0.5              +0.406                           0.0
# 327                 2.5                +0.6                           0.0
# 328                -1.0                 0.0                           0.0
# 329                -1.0                 0.0                           0.0
# 330                -1.0                 0.0                           0.0
# 331                -1.0                 0.0                           0.0
# 332                -1.0                 0.0                           0.0
# 333                -1.0                 0.0                           0.0
# 334                -1.0                 0.0                           0.0
# 335                -1.0                 0.0                           0.0
# 336                -1.0                 0.0                           0.0
# 337                -1.0                 0.0                           0.0
# 338                -1.0                 0.0                           0.0
# 339                -1.0                 0.0                           0.0
# 340                -1.0                 0.0                           0.0
# 341                -1.0                 0.0                           0.0
# 342                -1.0                 0.0                           0.0
# 343                -1.0                 0.0                           0.0
# 344                -1.0                 0.0                           0.0
# 345                -1.0                 0.0                           0.0
# 346                -1.0                 0.0                           0.0
# 347                -1.0                 0.0                           0.0
# 348                -1.0                 0.0                           0.0
# 349                -1.0                 0.0                           0.0
# 350                -1.0                 0.0                           0.0
#
#     electric quadrupole moment, in barn (10^-28 m^2)
# 0                                                  0
# 1                                           +0.00286
# 2                                                  0
# 3                                                  0
# 4                                                  0
# 5                                          -0.000806
# 6                                            -0.0400
# 7                                            +0.0529
# 8                                            +0.0845
# 9                                           +0.04059
# 10                                                 0
# 11                                                 0
# 12                                                 0
# 13                                          +0.02044
# 14                                                 0
# 15                                                 0
# 16                                           -0.0256
# 17                                                 0
# 18                                                 0
# 19                                                 0
# 20                                            +0.102
# 21                                                 0
# 22                                            +0.180
# 23                                            +0.104
# 24                                                 0
# 25                                            +0.199
# 26                                                 0
# 27                                           +0.1466
# 28                                                 0
# 29                                                 0
# ..                                               ...
# 321                                                0
# 322                                                0
# 323                                           +4.936
# 324                                                0
# 325                                            +3.87
# 326                                                0
# 327                                            +2.86
# 328                                                0
# 329                                                0
# 330                                                0
# 331                                                0
# 332                                                0
# 333                                                0
# 334                                                0
# 335                                                0
# 336                                                0
# 337                                                0
# 338                                                0
# 339                                                0
# 340                                                0
# 341                                                0
# 342                                                0
# 343                                                0
# 344                                                0
# 345                                                0
# 346                                                0
# 347                                                0
# 348                                                0
# 349                                                0
# 350                                                0
#
# [351 rows x 9 columns]

# %%
# We will use the fact that the list is already sorted by the symbol and just cut it up from there
# In future, might be able to do more robustly if we can somehow use this method on all the columns at once:
# isotope_table.groupby("symbol")['name'].apply(list)

# %%
# TODO: This is an ugly way of doing this, should figure out the pandas way of doing it

split_idx = [i for i in range(1,len(isotope_table["symbol"])) 
             if isotope_table["symbol"][i] != isotope_table["symbol"][i-1]]
split_table = np.split(isotope_table, split_idx)

# %%
# Make all the numbers floats
element_table = {}
for table in split_table:
    symbol = table['symbol'].iloc[0]
    element_table[symbol] = {}
    for j, col_label in enumerate(header):
        try:
            element_table[symbol][col_label] = table.values.T[j].astype('float')
        except ValueError:
            element_table[symbol][col_label] = table.values.T[j]

# %%
# Take advantage of the fact that spin is always positive

for key, table in element_table.items():
    table['percent spin'] = np.sum(
        np.heaviside(np.abs(table['spin quantum number']),0)*table['natural abundance, in percent'])
    
    table['mean g'] = np.sum(
        np.abs(table['nuclear g factor gn'])*table['natural abundance, in percent']/100)

# %%
bad_el = [key for key, table in element_table.items() if table['percent spin'] > 20]

# %% [markdown]
# # Search Materials Project for materials with good space groups/elements

# %%
api_key =  'fgkhjrsHTKukiIA6' # Found this from https://materialsproject.org/open in 'API keys' section
with mg.MPRester(api_key) as m:
    mat_data =  m.query(
        criteria={
            "spacegroup.number": {"$in": best_groups},
            "elements": {"$nin": bad_el},
            "band_gap": {"$gt": 1},
            "nelements": {"$lte": 2},
            "e_above_hull": {"$lte": 0.2} # Apparently lower is more stable. Diamond is 0.135
        },
        properties=["pretty_formula", "spacegroup.number", "e_above_hull", "exp", "doi", "spacegroup.symbol"]
    )

print(len(mat_data))
# [print(entry) for entry in mat_data];
# pd.DataFrame(mat_data)
# Out:
# 234

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(pd.DataFrame(mat_data).sort_values("pretty_formula"))
# Out:
#                   doi  e_above_hull  \
# 0    10.17188/1315564      0.036174
# 1    10.17188/1206386      0.000000
# 2    10.17188/1274272      0.000431
# 3    10.17188/1199275      0.000000
# 11   10.17188/1192460      0.159781
# 8    10.17188/1288490      0.131650
# 9    10.17188/1325047      0.025751
# 10   10.17188/1189576      0.000000
# 4    10.17188/1187544      0.000000
# 6    10.17188/1190987      0.000000
# 12   10.17188/1199791      0.000000
# 5    10.17188/1188961      0.000000
# 7    10.17188/1184814      0.000000
# 17   10.17188/1208346      0.161506
# 16   10.17188/1281384      0.136419
# 14   10.17188/1277704      0.145803
# 13   10.17188/1277705      0.142597
# 15   10.17188/1277856      0.141158
# 19   10.17188/1280467      0.010982
# 20   10.17188/1188309      0.007004
# 21               None      0.008678
# 23   10.17188/1200245      0.018960
# 26   10.17188/1267072      0.064707
# 30   10.17188/1201098      0.000000
# 27   10.17188/1279485      0.001520
# 24   10.17188/1192117      0.000000
# 25   10.17188/1190187      0.000000
# 28   10.17188/1191051      0.000000
# 29   10.17188/1274966      0.034393
# 31   10.17188/1350296      0.118833
# 32   10.17188/1195334      0.000000
# 33               None      0.062963
# 36   10.17188/1194409      0.000000
# 34               None      0.003436
# 35   10.17188/1318416      0.121121
# 37   10.17188/1294861      0.059126
# 38   10.17188/1308379      0.103816
# 39               None      0.113487
# 41   10.17188/1208347      0.003795
# 40   10.17188/1278112      0.048942
# 43               None      0.052177
# 44   10.17188/1291016      0.014150
# 42   10.17188/1185101      0.000000
# 46   10.17188/1289405      0.003750
# 45   10.17188/1199276      0.001933
# 47   10.17188/1277779      0.008262
# 48   10.17188/1199278      0.000000
# 52   10.17188/1277718      0.000000
# 51   10.17188/1314482      0.002302
# 49   10.17188/1273832      0.001896
# 50   10.17188/1315193      0.000969
# 56               None      0.075342
# 60               None      0.135350
# 62               None      0.062976
# 55               None      0.112790
# 64               None      0.039410
# 53   10.17188/1189109      0.000000
# 54               None      0.036997
# 59   10.17188/1189338      0.015651
# 63   10.17188/1189417      0.000000
# 57   10.17188/1189337      0.000000
# 61   10.17188/1187342      0.014114
# 58   10.17188/1189339      0.000774
# 65   10.17188/1187564      0.000000
# 67   10.17188/1193796      0.000000
# 66               None      0.136861
# 68   10.17188/1322389      0.164697
# 201  10.17188/1311837      0.000000
# 200              None      0.016717
# 202  10.17188/1299376      0.001007
# 122  10.17188/1287624      0.000000
# 193  10.17188/1201732      0.018328
# 223              None      0.079116
# 224  10.17188/1313539      0.079715
# 225  10.17188/1313540      0.061979
# 226              None      0.109324
# 227              None      0.056335
# 228              None      0.000000
# 18   10.17188/1282015      0.001197
# 163  10.17188/1188725      0.134000
# 162  10.17188/1206432      0.016247
# 161  10.17188/1269436      0.015152
# 159              None      0.100970
# 164  10.17188/1269359      0.008247
# 157              None      0.007664
# 155  10.17188/1277269      0.028141
# 153  10.17188/1270666      0.004363
# 152  10.17188/1276392      0.159572
# 151              None      0.013004
# 138  10.17188/1263241      0.011551
# 147  10.17188/1277237      0.014205
# 146  10.17188/1277230      0.032357
# 144  10.17188/1277226      0.014013
# 143  10.17188/1271808      0.015221
# 142  10.17188/1267679      0.039424
# 140  10.17188/1279857      0.015349
# 139  10.17188/1270217      0.073296
# 166  10.17188/1267780      0.098288
# 136  10.17188/1277245      0.008429
# 135  10.17188/1267945      0.013044
# 134              None      0.012720
# 148  10.17188/1281237      0.017291
# 167  10.17188/1279834      0.022620
# 181  10.17188/1268943      0.008571
# 171  10.17188/1183680      0.196038
# 132  10.17188/1277233      0.011092
# 199  10.17188/1271309      0.097953
# 198  10.17188/1281938      0.012664
# 196              None      0.010811
# 195  10.17188/1263373      0.011679
# 194  10.17188/1281939      0.012387
# 192  10.17188/1277274      0.018124
# 191  10.17188/1277227      0.008811
# 189  10.17188/1269629      0.143932
# 188              None      0.015596
# 187  10.17188/1268854      0.009844
# 186  10.17188/1271743      0.169201
# 185  10.17188/1277259      0.010549
# 183  10.17188/1267819      0.008797
# 182  10.17188/1279837      0.011518
# 180  10.17188/1270084      0.031653
# 179  10.17188/1279847      0.029099
# 178  10.17188/1279859      0.012714
# 177  10.17188/1267252      0.000000
# 175  10.17188/1268082      0.017679
# 174  10.17188/1271021      0.042097
# 173  10.17188/1268872      0.009391
# 172  10.17188/1187397      0.012693
# 168  10.17188/1267090      0.149595
# 131  10.17188/1268027      0.199244
# 116  10.17188/1268828      0.018040
# 129  10.17188/1281937      0.011747
# 104  10.17188/1277225      0.025276
# 102              None      0.010426
# 101  10.17188/1277271      0.022428
# 99   10.17188/1277270      0.023601
# 98   10.17188/1267192      0.030047
# 97   10.17188/1268867      0.177085
# 95   10.17188/1271100      0.160356
# 93   10.17188/1283559      0.031528
# 92   10.17188/1271279      0.091772
# 130              None      0.015045
# 90   10.17188/1269740      0.011152
# 89   10.17188/1269658      0.056243
# 88               None      0.127003
# 87   10.17188/1268035      0.010844
# 86   10.17188/1277229      0.015516
# 83   10.17188/1277276      0.138762
# 82   10.17188/1277235      0.011567
# 81   10.17188/1271981      0.146084
# 79   10.17188/1270571      0.009751
# 78   10.17188/1279851      0.025365
# 76               None      0.056476
# 75               None      0.016376
# 74               None      0.016910
# 73   10.17188/1277265      0.033460
# 71   10.17188/1267767      0.005082
# 70               None      0.017225
# 69   10.17188/1269913      0.065727
# 105  10.17188/1277241      0.013328
# 106  10.17188/1280490      0.011176
# 91   10.17188/1269152      0.134861
# 128  10.17188/1271088      0.136640
# 123  10.17188/1268992      0.040617
# 112              None      0.026498
# 117  10.17188/1270814      0.022676
# 111  10.17188/1277273      0.013877
# 115  10.17188/1269163      0.101435
# 118  10.17188/1271149      0.026082
# 113  10.17188/1271167      0.025848
# 110  10.17188/1270545      0.011628
# 120  10.17188/1277268      0.013936
# 125  10.17188/1277278      0.024634
# 121  10.17188/1277264      0.027768
# 109  10.17188/1309176      0.010639
# 124  10.17188/1277234      0.010804
# 119  10.17188/1279838      0.009543
# 212  10.17188/1291045      0.051746
# 211  10.17188/1191511      0.000000
# 215              None      0.005719
# 217  10.17188/1197372      0.003817
# 213  10.17188/1274334      0.000000
# 184  10.17188/1272823      0.000000
# 77   10.17188/1320941      0.191431
# 96   10.17188/1319438      0.068559
# 158  10.17188/1322405      0.161990
# 165  10.17188/1289755      0.056997
# 208              None      0.010517
# 207  10.17188/1274574      0.065297
# 214  10.17188/1312840      0.043629
# 22   10.17188/1201147      0.061640
# 94   10.17188/1289328      0.090132
# 127  10.17188/1289589      0.050893
# 197  10.17188/1183681      0.000000
# 154  10.17188/1201270      0.000000
# 209  10.17188/1187413      0.000000
# 203  10.17188/1194647      0.010651
# 218  10.17188/1201795      0.000000
# 229  10.17188/1194783      0.000000
# 231  10.17188/1356027      0.025650
# 233  10.17188/1354984      0.028515
# 232  10.17188/1350911      0.024206
# 100  10.17188/1200720      0.020129
# 149  10.17188/1280229      0.000000
# 107  10.17188/1318543      0.061036
# 190  10.17188/1184648      0.037206
# 114  10.17188/1200577      0.178801
# 150  10.17188/1207597      0.006387
# 80   10.17188/1203774      0.082192
# 126              None      0.082819
# 103  10.17188/1320078      0.042351
# 170  10.17188/1206378      0.004507
# 133              None      0.004772
# 108              None      0.003868
# 176              None      0.005010
# 141  10.17188/1193469      0.000088
# 85               None      0.000708
# 145  10.17188/1194456      0.000000
# 210  10.17188/1356010      0.000951
# 205  10.17188/1354959      0.002088
# 206  10.17188/1197614      0.000227
# 220  10.17188/1192989      0.000000
# 221  10.17188/1356057      0.000275
# 222  10.17188/1354964      0.001447
# 72   10.17188/1197511      0.147686
# 204  10.17188/1187297      0.000387
# 216  10.17188/1188456      0.000000
# 219  10.17188/1275209      0.159595
# 230  10.17188/1197153      0.000000
# 156  10.17188/1303781      0.055124
# 84   10.17188/1200956      0.036241
# 169  10.17188/1289413      0.014889
# 160  10.17188/1191294      0.068903
# 137  10.17188/1303780      0.050441
#
#                                                    exp pretty_formula  \
# 0                                         {'tags': []}          Ac2S3
# 1                                         {'tags': []}          Ac2S3
# 2    {'tags': ['Argon - HP', 'High pressure experim...             Ar
# 3                                  {'tags': ['Argon']}             Ar
# 11   {'tags': ['Barium carbide (1/2)', 'High pressu...           BaC2
# 8       {'tags': ['High pressure experimental phase']}            BaO
# 9       {'tags': ['High pressure experimental phase']}            BaO
# 10   {'tags': ['Calcium oxide', 'Barium oxide (1/1)...            BaO
# 4    {'tags': ['Barium peroxide', 'High pressure ex...           BaO2
# 6    {'tags': ['Barium sulfide', 'Barium sulfide (1...            BaS
# 12   {'tags': ['Barium trisulfide', 'Barium trio-tr...           BaS3
# 5                        {'tags': ['Barium selenide']}           BaSe
# 7                       {'tags': ['Barium telluride']}           BaTe
# 17      {'tags': ['Diamond', 'Lonsdaleite', 'Carbon']}              C
# 16   {'tags': ['Diamond 3C', 'Diamond', 'High press...              C
# 14                  {'tags': ['Diamond 4H', 'Carbon']}              C
# 13                  {'tags': ['Diamond 6H', 'Carbon']}              C
# 15                  {'tags': ['Diamond 8H', 'Carbon']}              C
# 19   {'tags': ['High pressure experimental phase', ...            CO2
# 20   {'tags': ['High pressure experimental phase', ...            CO2
# 21   {'tags': ['High pressure experimental phase', ...            CO2
# 23   {'tags': ['Calcium carbide (1/2) - I', 'Calciu...           CaC2
# 26                                        {'tags': []}            CaO
# 30   {'tags': ['Calcium oxide', 'Calcium oxide (1/1...            CaO
# 27                      {'tags': ['Calcium peroxide']}           CaO2
# 24          {'tags': ['Calcium sulfide', 'Oldhamite']}            CaS
# 25                      {'tags': ['Calcium selenide']}           CaSe
# 28   {'tags': ['Calcium telturide', 'Calcium tellur...           CaTe
# 29   {'tags': ['High pressure experimental phase', ...           CaTe
# 31   {'tags': ['Cerium dioxide - rutile-type, unsta...           CeO2
# 32   {'tags': ['Cerianite-(Ce)', 'Cerium dioxide - ...           CeO2
# 33                                        {'tags': []}          CeSe2
# 36   {'tags': ['Chromium oxide', 'High pressure exp...          Cr2O3
# 34                                        {'tags': []}            CrO
# 35                                        {'tags': []}           CrO2
# 37                                        {'tags': []}        Fe14O15
# 38                                        {'tags': []}            FeO
# 39                                        {'tags': []}            FeO
# 41   {'tags': ['Germanium dioxide', 'High pressure ...           GeO2
# 40             {'tags': ['Germanium sulfide - delta']}           GeS2
# 43                   {'tags': ['Germanium disulfide']}           GeS2
# 44   {'tags': ['High pressure experimental phase', ...           GeS2
# 42   {'tags': ['Germanium selenide', 'High pressure...          GeSe2
# 46                                        {'tags': []}             He
# 45   {'tags': ['Helium - beta', 'Helium - alpha', '...             He
# 47   {'tags': ['High pressure experimental phase', ...             He
# 48   {'tags': ['Helium - alpha', 'Helium - gamma', ...             He
# 52                               {'tags': ['Krypton']}             Kr
# 51                                        {'tags': []}             Kr
# 49                               {'tags': ['Krypton']}             Kr
# 50                                        {'tags': []}             Kr
# 56                                        {'tags': []}            MgO
# 60                                        {'tags': []}            MgO
# 62                                        {'tags': []}            MgO
# 55                                        {'tags': []}            MgO
# 64                                        {'tags': []}            MgO
# 53   {'tags': ['Magnesium oxide', 'High pressure ex...            MgO
# 54                                        {'tags': []}            MgO
# 59                     {'tags': ['Magnesium sulfide']}            MgS
# 63   {'tags': ['Magnesium sulfide (1/1)', 'Magnesiu...            MgS
# 57                    {'tags': ['Magnesium selenide']}           MgSe
# 61   {'tags': ['Magnesium selenide', 'Magnesium sel...           MgSe
# 58   {'tags': ['Magnesium telluride', 'Magnesium te...           MgTe
# 65   {'tags': ['High pressure experimental phase', ...             Ne
# 67   {'tags': ['Bunsenite', 'Nickel oxide', 'Nickel...            NiO
# 66                                        {'tags': []}           NiO2
# 68                                        {'tags': []}           NiO2
# 201                                       {'tags': []}          Pm2S3
# 200                                       {'tags': []}         Pm2Se3
# 202  {'tags': ['Sulfur (8)- alpha', 'Sulfur - alpha...              S
# 122  {'tags': ['Selenium oxide', 'High pressure exp...           SeO2
# 193              {'tags': ['Tetraselenium(VI) oxide']}           SeO3
# 223                              {'tags': ['Silicon']}             Si
# 224                                       {'tags': []}             Si
# 225              {'tags': ['Silicon (46)', 'Silicon']}             Si
# 226                              {'tags': ['Silicon']}             Si
# 227                              {'tags': ['Silicon']}             Si
# 228  {'tags': ['Tc4Si7', 'chimney-ladder structure'...         Si7Tc4
# 18   {'tags': ['Silicon carbide - ZB-type', 'Silico...            SiC
# 163           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 162  {'tags': ['Silicon oxide (192/384)', 'High pre...           SiO2
# 161  {'tags': ['Zeolite TNU-10', 'Silicon oxide (72...           SiO2
# 159                      {'tags': ['Silicon dioxide']}           SiO2
# 164  {'tags': ['Zeolite GUS-1', 'Silicon oxide (32/...           SiO2
# 157          {'tags': ['Sodalite', 'Silicon dioxide']}           SiO2
# 155                        {'tags': ['SiO2 Zeolites']}           SiO2
# 153                                       {'tags': []}           SiO2
# 152           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 151                                       {'tags': []}           SiO2
# 138                                       {'tags': []}           SiO2
# 147                        {'tags': ['SiO2 Zeolites']}           SiO2
# 146                        {'tags': ['SiO2 Zeolites']}           SiO2
# 144                        {'tags': ['SiO2 Zeolites']}           SiO2
# 143  {'tags': ['Zeolite ZSM-39', 'Dodecasil 3C', 'S...           SiO2
# 142           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 140                        {'tags': ['SiO2 Zeolites']}           SiO2
# 139           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 166                      {'tags': ['Silicon dioxide']}           SiO2
# 136                        {'tags': ['SiO2 Zeolites']}           SiO2
# 135           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 134                                       {'tags': []}           SiO2
# 148  {'tags': ['Zeolite EU-1', 'Silicon oxide', 'Te...           SiO2
# 167                        {'tags': ['SiO2 Zeolites']}           SiO2
# 181           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 171  {'tags': ['Silicon oxide', 'Silicon dioxide', ...           SiO2
# 132                        {'tags': ['SiO2 Zeolites']}           SiO2
# 199                      {'tags': ['Silicon dioxide']}           SiO2
# 198  {'tags': ['Quartz high', 'Silicon dioxide - HT']}           SiO2
# 196                                       {'tags': []}           SiO2
# 195                                       {'tags': []}           SiO2
# 194  {'tags': ['Silicon oxide', 'Cristobalite beta ...           SiO2
# 192                        {'tags': ['SiO2 Zeolites']}           SiO2
# 191                        {'tags': ['SiO2 Zeolites']}           SiO2
# 189             {'tags': ['Zeolite', 'Silicon oxide']}           SiO2
# 188                                       {'tags': []}           SiO2
# 187  {'tags': ['Zeolite Sigma-2', 'Silicon dioxide ...           SiO2
# 186           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 185                        {'tags': ['SiO2 Zeolites']}           SiO2
# 183           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 182                        {'tags': ['SiO2 Zeolites']}           SiO2
# 180           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 179                        {'tags': ['SiO2 Zeolites']}           SiO2
# 178                        {'tags': ['SiO2 Zeolites']}           SiO2
# 177  {'tags': ['Silicon oxide', 'Silicon dioxide', ...           SiO2
# 175  {'tags': ['Zeolite beta', 'Silicon oxide (32/6...           SiO2
# 174             {'tags': ['Zeolite', 'Silicon oxide']}           SiO2
# 173           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 172                          {'tags': ['Quartz high']}           SiO2
# 168           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 131           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 116           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 129  {'tags': ['Tridymite 2H high (Gibbs Model)', '...           SiO2
# 104                        {'tags': ['SiO2 Zeolites']}           SiO2
# 102                                       {'tags': []}           SiO2
# 101  {'tags': ['Zeolite ITQ-7', 'Silicon oxide (64/...           SiO2
# 99                         {'tags': ['SiO2 Zeolites']}           SiO2
# 98                                        {'tags': []}           SiO2
# 97            {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 95            {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 93                 {'tags': ['Silicon oxide (48/96)']}           SiO2
# 92                                        {'tags': []}           SiO2
# 130                                       {'tags': []}           SiO2
# 90              {'tags': ['Zeolite', 'Silicon oxide']}           SiO2
# 89              {'tags': ['Zeolite', 'Silicon oxide']}           SiO2
# 88                                        {'tags': []}           SiO2
# 87                                        {'tags': []}           SiO2
# 86                         {'tags': ['SiO2 Zeolites']}           SiO2
# 83                         {'tags': ['SiO2 Zeolites']}           SiO2
# 82                         {'tags': ['SiO2 Zeolites']}           SiO2
# 81            {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 79        {'tags': ['Zeolite RUB-3', 'Silicon oxide']}           SiO2
# 78                         {'tags': ['SiO2 Zeolites']}           SiO2
# 76                                        {'tags': []}           SiO2
# 75   {'tags': ['Zeolite RUB-24', 'Silicon oxide (32...           SiO2
# 74   {'tags': ['Zeolite ITQ-1', 'Silicon oxide (72/...           SiO2
# 73                         {'tags': ['SiO2 Zeolites']}           SiO2
# 71                       {'tags': ['Silicon dioxide']}           SiO2
# 70                                        {'tags': []}           SiO2
# 69            {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 105                        {'tags': ['SiO2 Zeolites']}           SiO2
# 106  {'tags': ['Silicon oxide', 'Silicon oxide (96/...           SiO2
# 91            {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 128           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 123           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 112           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 117           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 111                        {'tags': ['SiO2 Zeolites']}           SiO2
# 115                                       {'tags': []}           SiO2
# 118           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 113           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 110           {'tags': ['Zeolite', 'Silicon dioxide']}           SiO2
# 120                        {'tags': ['SiO2 Zeolites']}           SiO2
# 125                        {'tags': ['SiO2 Zeolites']}           SiO2
# 121                        {'tags': ['SiO2 Zeolites']}           SiO2
# 109        {'tags': ['Silicon oxide', 'Dodecasil 1H']}           SiO2
# 124                        {'tags': ['SiO2 Zeolites']}           SiO2
# 119                        {'tags': ['SiO2 Zeolites']}           SiO2
# 212  {'tags': ['Silicon disulfide', 'Silicon sulfid...           SiS2
# 211  {'tags': ['Silicon disulfide', 'Silicon sulfid...           SiS2
# 215                                       {'tags': []}          SiSe2
# 217                                       {'tags': []}          SiSe2
# 213                     {'tags': ['Silicon selenide']}          SiSe2
# 184  {'tags': ['Tin dioxide - rutile-type', 'Tin(IV...           SnO2
# 77                                        {'tags': []}           SnO2
# 96                                        {'tags': []}           SnO2
# 158                                       {'tags': []}           SnO2
# 165                                       {'tags': []}           SnO2
# 208                        {'tags': ['Tin disulfide']}           SnS2
# 207                                       {'tags': []}           SnS2
# 214                         {'tags': ['Tin selenide']}           SnSe
# 22   {'tags': ['Strontium carbide (1/2) - I', 'Stro...           SrC2
# 94                                        {'tags': []}            SrO
# 127                                       {'tags': []}            SrO
# 197  {'tags': ['Strontium oxide (1/1)', 'Strontium ...            SrO
# 154                   {'tags': ['Strontium peroxide']}           SrO2
# 209  {'tags': ['Strontium sulfide (1/1)', 'Strontiu...            SrS
# 203  {'tags': ['High pressure experimental phase', ...           SrS2
# 218  {'tags': ['Strontium selenide', 'Strontium sel...           SrSe
# 229                  {'tags': ['Strontium telluride']}           SrTe
# 231                                       {'tags': []}           Te2W
# 233                                       {'tags': []}           Te2W
# 232             {'tags': ['Tungsten telluride (1/2)']}           Te2W
# 100  {'tags': ['Tellurium(VI) oxide', 'Tellurium tr...           TeO3
# 149  {'tags': ['Thoria', 'Thorianite', 'Thorium oxi...           ThO2
# 107                                       {'tags': []}           TiO2
# 190  {'tags': ['Titanium oxide - C', 'Titanium oxid...           TiO2
# 114                                       {'tags': []}           TiO2
# 150  {'tags': ['Titanium oxide', 'Titanium dioxide'...           TiO2
# 80                                        {'tags': []}            UO3
# 126             {'tags': ['Uranium trioxide - gamma']}            UO3
# 103                                       {'tags': []}            WO2
# 170                    {'tags': ['Tungsten trioxide']}            WO3
# 133                    {'tags': ['Tungsten trioxide']}            WO3
# 108  {'tags': ['Tin tungsten oxide (0.3/1/3)', 'Tin...            WO3
# 176                       {'tags': ['Tungsten oxide']}            WO3
# 141                       {'tags': ['Tungsten oxide']}            WO3
# 85                        {'tags': ['Tungsten oxide']}            WO3
# 145  {'tags': ['Tungsten trioxide - HT', 'Lithium t...            WO3
# 210                                       {'tags': []}            WS2
# 205                                       {'tags': []}            WS2
# 206  {'tags': ['Tungsten sulfide (1/2)', 'Tungsteni...            WS2
# 220              {'tags': ['Tungsten selenide (1/2)']}           WSe2
# 221                                       {'tags': []}           WSe2
# 222                                       {'tags': []}           WSe2
# 72   {'tags': ['High pressure experimental phase', ...            ZnO
# 204  {'tags': ['Zinc sulfide (1/1)', 'Sphalerite', ...            ZnS
# 216  {'tags': ['Zinc selenide', 'Zinc selenide - th...           ZnSe
# 219                  {'tags': ['Zinc selenide (1/1)']}           ZnSe
# 230  {'tags': ['High pressure experimental phase', ...           ZnTe
# 156                                       {'tags': []}           ZrO2
# 84   {'tags': ['Zirconia', 'Zirconia (nanocrystalli...           ZrO2
# 169                                       {'tags': []}           ZrO2
# 160  {'tags': ['Baddeleyite', 'Zirconia (nanocrysta...           ZrO2
# 137                                       {'tags': []}           ZrO2
#
#      spacegroup.number spacegroup.symbol
# 0                  167              R-3c
# 1                  122             I-42d
# 2                  194          P6_3/mmc
# 3                  225             Fm-3m
# 11                 139            I4/mmm
# 8                  129            P4/nmm
# 9                  194          P6_3/mmc
# 10                 225             Fm-3m
# 4                  139            I4/mmm
# 6                  225             Fm-3m
# 12                 113           P-42_1m
# 5                  225             Fm-3m
# 7                  225             Fm-3m
# 17                 194          P6_3/mmc
# 16                 227             Fd-3m
# 14                 194          P6_3/mmc
# 13                 194          P6_3/mmc
# 15                 194          P6_3/mmc
# 19                 136          P4_2/mnm
# 20                 136          P4_2/mnm
# 21                 167              R-3c
# 23                 139            I4/mmm
# 26                 194          P6_3/mmc
# 30                 225             Fm-3m
# 27                 139            I4/mmm
# 24                 225             Fm-3m
# 25                 225             Fm-3m
# 28                 225             Fm-3m
# 29                 194          P6_3/mmc
# 31                 136          P4_2/mnm
# 32                 225             Fm-3m
# 33                 194          P6_3/mmc
# 36                 167              R-3c
# 34                  66              Cccm
# 35                  87              I4/m
# 37                  87              I4/m
# 38                 190             P-62c
# 39                 194          P6_3/mmc
# 41                 136          P4_2/mnm
# 40                 142          I4_1/acd
# 43                 137          P4_2/nmc
# 44                 122             I-42d
# 42                 122             I-42d
# 46                 191            P6/mmm
# 45                 194          P6_3/mmc
# 47                 225             Fm-3m
# 48                 229             Im-3m
# 52                 225             Fm-3m
# 51                 229             Im-3m
# 49                 194          P6_3/mmc
# 50                 194          P6_3/mmc
# 56                  72              Ibam
# 60                 223             Pm-3n
# 62                  72              Ibam
# 55                 192            P6/mcc
# 64                 194          P6_3/mmc
# 53                 225             Fm-3m
# 54                 194          P6_3/mmc
# 59                 216             F-43m
# 63                 225             Fm-3m
# 57                 216             F-43m
# 61                 225             Fm-3m
# 58                 216             F-43m
# 65                 225             Fm-3m
# 67                 225             Fm-3m
# 66                 227             Fd-3m
# 68                 194          P6_3/mmc
# 201                167              R-3c
# 200                122             I-42d
# 202                 70              Fddd
# 122                135          P4_2/mbc
# 193                114           P-42_1c
# 223                191            P6/mmm
# 224                217             I-43m
# 225                223             Pm-3n
# 226                217             I-43m
# 227                194          P6_3/mmc
# 228                116             P-4c2
# 18                 216             F-43m
# 163                227             Fd-3m
# 162                227             Fd-3m
# 161                 69              Fmmm
# 159                 21              C222
# 164                 21              C222
# 157                217             I-43m
# 155                126            P4/nnc
# 153                182            P6_322
# 152                 85              P4/n
# 151                187             P-6m2
# 138                175              P6/m
# 147                225             Fm-3m
# 146                124            P4/mcc
# 144                131          P4_2/mmc
# 143                227             Fd-3m
# 142                141          I4_1/amd
# 140                139            I4/mmm
# 139                118             P-4n2
# 166                140            I4/mcm
# 136                229             Im-3m
# 135                140            I4/mcm
# 134                194          P6_3/mmc
# 148                 67              Cmme
# 167                131          P4_2/mmc
# 181                141          I4_1/amd
# 171                136          P4_2/mnm
# 132                129            P4/nmm
# 199                114           P-42_1c
# 198                180            P6_222
# 196                139            I4/mmm
# 195                191            P6/mmm
# 194                227             Fd-3m
# 192                139            I4/mmm
# 191                139            I4/mmm
# 189                162             P-31m
# 188                141          I4_1/amd
# 187                141          I4_1/amd
# 186                 98            I4_122
# 185                 81               P-4
# 183                140            I4/mcm
# 182                139            I4/mmm
# 180                121             I-42m
# 179                119             I-4m2
# 178                229             Im-3m
# 177                122             I-42d
# 175                131          P4_2/mmc
# 174                194          P6_3/mmc
# 173                135          P4_2/mbc
# 172                181            P6_422
# 168                 98            I4_122
# 131                132          P4_2/mcm
# 116                 70              Fddd
# 129                194          P6_3/mmc
# 104                115             P-4m2
# 102                139            I4/mmm
# 101                131          P4_2/mmc
# 99                 141          I4_1/amd
# 98                 155               R32
# 97                  70              Fddd
# 95                  68              Ccce
# 93                 191            P6/mmm
# 92                 121             I-42m
# 130                194          P6_3/mmc
# 90                 193          P6_3/mcm
# 89                 223             Pm-3n
# 88                  87              I4/m
# 87                  82               I-4
# 86                 229             Im-3m
# 83                 217             I-43m
# 82                  67              Cmme
# 81                 116             P-4c2
# 79                 129            P4/nmm
# 78                 141          I4_1/amd
# 76                 230             Ia-3d
# 75                 141          I4_1/amd
# 74                 191            P6/mmm
# 73                  66              Cccm
# 71                  82               I-4
# 70                 176            P6_3/m
# 69                 223             Pm-3n
# 105                230             Ia-3d
# 106                119             I-4m2
# 91                 229             Im-3m
# 128                230             Ia-3d
# 123                229             Im-3m
# 112                142          I4_1/acd
# 117                133          P4_2/nbc
# 111                 72              Ibam
# 115                 68              Ccce
# 118                194          P6_3/mmc
# 113                225             Fm-3m
# 110                230             Ia-3d
# 120                129            P4/nmm
# 125                138          P4_2/ncm
# 121                119             I-4m2
# 109                191            P6/mmm
# 124                141          I4_1/amd
# 119                223             Pm-3n
# 212                122             I-42d
# 211                 72              Ibam
# 215                 72              Ibam
# 217                140            I4/mcm
# 213                 72              Ibam
# 184                136          P4_2/mnm
# 77                 227             Fd-3m
# 96                  87              I4/m
# 158                194          P6_3/mmc
# 165                141          I4_1/amd
# 208                227             Fd-3m
# 207                122             I-42d
# 214                129            P4/nmm
# 22                 139            I4/mmm
# 94                 194          P6_3/mmc
# 127                194          P6_3/mmc
# 197                225             Fm-3m
# 154                139            I4/mmm
# 209                225             Fm-3m
# 203                140            I4/mcm
# 218                225             Fm-3m
# 229                225             Fm-3m
# 231                187             P-6m2
# 233                187             P-6m2
# 232                194          P6_3/mmc
# 100                167              R-3c
# 149                225             Fm-3m
# 107                 87              I4/m
# 190                136          P4_2/mnm
# 114                227             Fd-3m
# 150                141          I4_1/amd
# 80                 141          I4_1/amd
# 126                 70              Fddd
# 103                 87              I4/m
# 170                193          P6_3/mcm
# 133                193          P6_3/mcm
# 108                113           P-42_1m
# 176                191            P6/mmm
# 141                130            P4/ncc
# 85                 113           P-42_1m
# 145                129            P4/nmm
# 210                187             P-6m2
# 205                187             P-6m2
# 206                194          P6_3/mmc
# 220                194          P6_3/mmc
# 221                187             P-6m2
# 222                187             P-6m2
# 72                 225             Fm-3m
# 204                216             F-43m
# 216                216             F-43m
# 219                129            P4/nmm
# 230                216             F-43m
# 156                 85              P4/n
# 84                 137          P4_2/nmc
# 169                141          I4_1/amd
# 160                225             Fm-3m
# 137                136          P4_2/mnm
